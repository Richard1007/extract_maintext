# %%
import sys
# !{sys.executable} -m pip install crossrefapi
# Out:
# Collecting crossrefapi
#   Downloading crossrefapi-1.5.0.tar.gz (20 kB)
# Requirement already satisfied: requests>=2.11.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from crossrefapi) (2.28.1)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from requests>=2.11.1->crossrefapi) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from requests>=2.11.1->crossrefapi) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from requests>=2.11.1->crossrefapi) (2022.9.24)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from requests>=2.11.1->crossrefapi) (1.26.12)
# Using legacy 'setup.py install' for crossrefapi, since package 'wheel' is not installed.
# Installing collected packages: crossrefapi
#     Running setup.py install for crossrefapi ... done
# Successfully installed crossrefapi-1.5.0
# WARNING: You are using pip version 21.2.4; however, version 22.2.2 is available.
# You should consider upgrading via the '/usr/local/bin/python3.10 -m pip install --upgrade pip' command.

# %%
from crossref.restful import Works
from crossref.restful import Journals
from time import sleep
import numpy as np
from bs4 import BeautifulSoup, NavigableString
import csv
import pandas as pd
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import pandas as pd
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
import random

# %%
doi_html = '/Users/richardpang/Desktop/extract_maintext/doi html/doi2011-2015.html'
doi_lst = []
with open(doi_html, 'r') as f:
    soup = BeautifulSoup(f, 'html.parser')
titles=soup.find_all('dl',{'class':"print-citation"})
for i in range(len(titles)):
    
    if "DOI:" in titles[i].get_text():
        doi = titles[i].get_text().split('DOI: ')[1].split(' ')[0][:-1]
        print(doi)
    # print(doi)
        doi_lst.append(doi)
df=pd.DataFrame(doi_lst)
len(df)
# Out:
# 10.1509/jmkg.75.4.136
# 10.1509/jm.14.0169
# 10.1509/jm.09.0081
# 10.1509/jm.12.0078
# 10.1509/jm.11.0330
# 10.1509/jm.11.0130
# 10.1509/jmkg.75.2.18
# 10.1509/jmkg.75.2.75
# 10.1509/jm.12.0106
# 10.1509/jm.11.0255
# 10.1509/jm.11.0297
# 10.1509/jmkg.75.3.1
# 10.1509/jmkg.75.5.53
# 10.1509/jm.09.0581
# 10.1509/jm.13.0410
# 10.1509/jm.13.0437
# 10.1509/jm.11.0105
# 10.1509/jm.10.0400
# 10.1509/jm.11.0145
# 10.1509/jm.09.0339
# 10.1509/jm.11.0485
# 10.1509/jmkg.75.4.196
# 10.1509/jm.13.0524
# 10.1509/jm.13.0228
# 10.1509/jm.10.0537
# 10.1509/jm.11.0544
# 10.1509/jm.14.0003
# 10.1509/jm.09.0589
# 10.1509/jmkg.75.4.183
# 10.1509/jmkg.75.3.18
# 10.1509/jm.13.0272
# 10.1509/jm.12.0190
# 10.1509/jmkg.75.3.66
# 10.1509/jm.12.0051
# 10.1509/jmkg.75.2.124
# 10.1509/jm.12.0052
# 10.1509/jm.10.0205
# 10.1509/jm.11.0599
# 10.1509/jm.11.0403
# 10.1509/jm.13.0026
# 10.1509/jm.12.0089
# 10.1509/jm.11.0245
# 10.1509/jm.10.0418
# 10.1509/jm.12.0421
# 10.1509/jm.11.0310
# 10.1509/jm.12.0317
# 10.1509/jmkg.75.3.118
# 10.1509/jm.12.0442
# 10.1509/jm.09.0486
# 10.1509/jm.10.0033
# 10.1509/jm.09.0362
# 10.1509/jm.11.0424
# 10.1509/jmkg.75.2.36
# 10.1509/jm.14.0351
# 10.1509/jm.09.0308
# 10.1509/jm.11.0205
# 10.1509/jmkg.75.3.27
# 10.1509/jm.11.0570
# 10.1509/jm.11.0264
# 10.1509/jm.11.0592
# 10.1509/jmkg.75.4.35
# 10.1509/jmkg.75.1.78
# 10.1509/jm.10.0529
# 10.1509/jm.14.0357
# 10.1509/jmkg.75.4.94
# 10.1509/jm.12.0471
# 10.1509/jm.79.1.1
# 10.1509/jmkg.75.5.71
# 10.1509/jmkg.75.4.53
# 10.1509/jm.11.0181
# 10.1509/jm.10.0494
# 10.1509/jm.12.0179
# 10.1509/jm.13.0509
# 10.1509/jm.13.0312
# 10.1509/jmkg.75.1.31
# 10.1509/jm.75.6.editorial
# 10.1509/jmkg.75.4.1
# 10.1509/jm.12.0408
# 10.1509/jm.10.0448
# 10.1509/jmkg.75.4.21
# 10.1509/jm.10.0416
# 10.1509/jm.11.0454
# 10.1509/jm.12.0167
# 10.1509/jm.13.0387
# 10.1509/jm.12.0422
# 10.1509/jm.11.0423
# 10.1509/jm.14.0100
# 10.1509/jm.14.0288
# 10.1509/jm.10.0231
# 10.1509/jm.10.0202
# 10.1509/jm.10.0406
# 10.1509/jm.12.0021
# 10.1509/jm.14.0284
# 10.1509/jm.11.0251
# 10.1509/jm.09.0395
# 10.1509/jm.13.0280
# 10.1509/jmkg.75.4.166
# 10.1509/jm.13.0212
# 10.1509/jm.12.0328
# 10.1509/jm.10.0413
# 10.1509/jm.11.0217
# 10.1509/jmkg.75.4.128
# 10.1509/jmkg.75.1.16
# 10.1509/jm.13.0301
# 10.1509/jmkg.75.5.18
# 10.1509/jmkg.75.3.132
# 10.1509/jmkg.75.5.120
# 10.1509/jm.76.4.i
# 10.1509/jm.76.2.i
# 10.1509/jm.76.1.i
# 10.1509/jmkg.75.5.i
# 10.1509/jmkg.75.4.i
# 10.1509/jmkg.75.1.i
# 10.1509/jm.75.6.i
# 10.1509/jm.76.3.i
# 10.1509/jmkg.75.2.i
# 10.1509/jm.75.6.i
# 10.1509/jm.13.0300
# 10.1509/jm.12.0468
# 10.1509/jm.12.0459
# 10.1509/jm.10.0280
# 10.1509/jm.12.0529
# 10.1509/jm.08.0204
# 10.1509/jm.12.0325
# 10.1509/jm.12.0296
# 10.1509/jm.13.0220
# 10.1509/jm.10.0015
# 10.1509/jm.13.0479
# 10.1509/jm.13.0522
# 10.1509/jm.12.0314
# 10.1509/jm.12.0020
# 10.1509/jmkg.75.1.60
# 10.1509/jm.09.0487
# 10.1509/jmkg.75.4.225
# 10.1509/jm.10.0162
# 10.1509/jm.13.0075
# 10.1509/jm.11.0560
# 10.1509/jm.09.0094
# 10.1509/jm.13.0174
# 10.1509/jm.09.0199
# 10.1509/jm.10.0444
# 10.1509/jm.13.0059
# 10.1509/jm.13.0218
# 10.1509/jm.14.0199
# 10.1509/jm.13.0198
# 10.1509/jm.11.0528
# 10.1509/jm.11.0508
# 10.1509/jmkg.75.4.211
# 10.1509/jm.10.0441
# 10.1509/jm.11.0529
# 10.1509/jmkg.75.2.1
# 10.1509/jm.13.0253
# 10.1509/jmkg.75.3.99
# 10.1509/jm.11.0164
# 10.1509/jm.12.0228
# 10.1509/jm.12.0338
# 10.1509/jm.11.0112
# 10.1509/jmkg.75.3.83
# 10.1509/jm.11.0286
# 10.1509/jmkg.75.1.96
# 10.1509/jm.09.0363
# 10.1509/jmkg.75.1.46
# 10.1509/jm.14.0107
# 10.1509/jm.10.0271
# 10.1509/jmkg.75.4.132
# 10.1509/jm.11.0219
# 10.1509/jm.11.0566
# 10.1509/jm.10.0534
# 10.1509/jm.75.2.93
# 10.1509/jm.10.0419
# 10.1509/jm.10.0414
# 10.1509/jm.10.0088
# 10.1509/jm.12.0527
# 10.1509/jm.09.0420
# 10.1509/jm.14.0273
# 10.1509/jmkg.75.3.49
# 10.1509/jm.14.0091
# 10.1509/jm.12.0303
# 10.1509/jm.12.0060
# 10.1509/jm.09.0202
# 10.1509/jm.10.0209
# 10.1509/jm.10.0377
# 10.1509/jm.14.0444
# 10.1509/jm.11.0443
# 10.1509/jmkg.75.4.155
# 10.1509/jmkg.75.4.68
# 10.1509/jm.11.0173
# 10.1509/jm.11.0431
# 10.1509/jm.11.0316
# 10.1509/jm.11.0428
# 10.1509/jm.10.0348
# 10.1509/jmkg.75.4.110
# 10.1509/jmkg.75.4.3
# 10.1509/jmkg.75.5.34
# 10.1509/jm.14.0244
# 10.1509/jm.13.0263
# 10.1509/jm.11.0349
# 10.1509/jm.09.0209
# 10.1509/jm.09.0320
# 10.1509/jmkg.75.2.109
# 10.1509/jm.11.0436
# 10.1509/jm.10.0073
# 10.1509/jmkg.75.1.1
# 10.1509/jm.11.0011
# 10.1509/jm.14.0018
# 10.1509/jm.10.0522
# 10.1509/jmkg.75.5.88
# 10.1509/jm.13.0521
# 10.1509/jmkg.75.4.86
# 10.1509/jm.11.0356
# 10.1509/jm.13.0505
# 10.1509/jm.11.0495
# 10.1509/jm.13.0475
# 10.1509/jm.12.0151
# 10.1509/jm.10.0462
# 10.1509/jm.10.0145
# 10.1509/jm.11.0400
# 10.1509/jmkg.75.5.105
# 10.1509/jm.12.0196
# 10.1509/jm.13.0185
# 10.1509/jm.13.0286
# 10.1509/jm.10.0047
# 10.1509/jm.13.0490
# 10.1509/jm.11.0222
# 10.1509/jmkg.75.4.129
# 10.1509/jm.12.0056
# 10.1509/jm.15.0105
# 10.1509/jm.14.0202
# 10.1509/jm.10.0445
# 10.1509/jm.11.0463
# 10.1509/jm.12.0404
# 10.1509/jm.09.0416
# 10.1509/jm.10.0229
# 10.1509/jm.13.0303
# 10.1509/jm.11.0278
# 10.1509/jm.09.0512
# 10.1509/jm.09.0034
# 10.1509/jm.11.0610
# 10.1509/jm.11.0477
# 10.1509/jm.11.0510
# 10.1509/jm.10.0368
# 10.1509/jm.10.0443
# 10.1509/jmkg.75.2.55
# 10.1509/jm.11.0504
# 10.1509/jm.12.0344
# 10.1509/jm.11.0261
# 10.1509/jm.12.0166
# 10.1509/jm.10.0182
# 10.1509/jmkg.75.1.109
# 10.1509/jmkg.75.5.1
# 10.1509/jm.13.0104
# 10.1509/jm.11.0225
# 252

# %%
url = 'https://journals.sagepub.com/doi/full/'

# %%
url_lst = []
for i in range(len(doi_lst)):
    url = 'https://journals.sagepub.com/doi/full/' + doi_lst[i]
    url_lst.append(url)
len(url_lst)
# Out:
# 252

# %% [markdown]
# # Scraping

# %%
#For ChromeDriver version 79.0.3945.16 or over
options = Options()
options.add_argument('--disable-blink-features=AutomationControlled') 

#Open Browser
driver = webdriver.Chrome(executable_path='/Users/richardpang/.wdm/drivers/chromedriver/mac64/106.0.5249/chromedriver',options=options)
article_lst = []
count = 0
for url in url_lst:
# driver = webdriver.Chrome( '/Users/richardpang/.wdm/drivers/chromedriver/mac64/106.0.5249/chromedriver')
    driver.get(url)
    element = driver.find_elements(By.TAG_NAME, 'div')
    element = driver.find_elements(By.CLASS_NAME, 'core-container')
    # print(len(element))
    title = element[0].text.split('\n')[3]
    abstract = element[2].text.split('\n')[1]
    main_text = element[3].text
    article  = [title,abstract,main_text]
    article_lst.append(article)
    count += 1
    if count%10 ==0:
        print(count, 'articles have been collected.')
    sleep(np.random.randint(6, 7))
driver.quit()
article_df = pd.DataFrame(article_lst)
article_df
# Out:
# /var/folders/28/rtg76x2d1m791yxskrhmnffc0000gn/T/ipykernel_31147/3804376809.py:6: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(executable_path='/Users/richardpang/.wdm/drivers/chromedriver/mac64/106.0.5249/chromedriver',options=options)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [17], line 11
#       8 count = 0
#       9 for url in url_lst:
#      10 # driver = webdriver.Chrome( '/Users/richardpang/.wdm/drivers/chromedriver/mac64/106.0.5249/chromedriver')
# ---> 11     driver.get(url)
#      12     element = driver.find_elements(By.TAG_NAME, 'div')
#      13     element = driver.find_elements(By.CLASS_NAME, 'core-container')
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/selenium/webdriver/remote/webdriver.py:441, in WebDriver.get(self, url)
#     437 def get(self, url: str) -> None:
#     438     """
#     439     Loads a web page in the current browser session.
#     440     """
# --> 441     self.execute(Command.GET, {'url': url})
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/selenium/webdriver/remote/webdriver.py:427, in WebDriver.execute(self, driver_command, params)
#     424         params['sessionId'] = self.session_id
#     426 params = self._wrap_value(params)
# --> 427 response = self.command_executor.execute(driver_command, params)
#     428 if response:
#     429     self.error_handler.check_response(response)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/selenium/webdriver/remote/remote_connection.py:344, in RemoteConnection.execute(self, command, params)
#     342 data = utils.dump_json(params)
#     343 url = f"{self._url}{path}"
# --> 344 return self._request(command_info[0], url, body=data)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/selenium/webdriver/remote/remote_connection.py:366, in RemoteConnection._request(self, method, url, body)
#     363     body = None
#     365 if self.keep_alive:
# --> 366     response = self._conn.request(method, url, body=body, headers=headers)
#     367     statuscode = response.status
#     368 else:
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/urllib3/request.py:78, in RequestMethods.request(self, method, url, fields, headers, **urlopen_kw)
#      74     return self.request_encode_url(
#      75         method, url, fields=fields, headers=headers, **urlopen_kw
#      76     )
#      77 else:
# ---> 78     return self.request_encode_body(
#      79         method, url, fields=fields, headers=headers, **urlopen_kw
#      80     )
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/urllib3/request.py:170, in RequestMethods.request_encode_body(self, method, url, fields, headers, encode_multipart, multipart_boundary, **urlopen_kw)
#     167 extra_kw["headers"].update(headers)
#     168 extra_kw.update(urlopen_kw)
# --> 170 return self.urlopen(method, url, **extra_kw)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/urllib3/poolmanager.py:376, in PoolManager.urlopen(self, method, url, redirect, **kw)
#     374     response = conn.urlopen(method, url, **kw)
#     375 else:
# --> 376     response = conn.urlopen(method, u.request_uri, **kw)
#     378 redirect_location = redirect and response.get_redirect_location()
#     379 if not redirect_location:
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/urllib3/connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     700     self._prepare_proxy(conn)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#     717 response_conn = conn if not release_conn else None
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/urllib3/connectionpool.py:449, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     444             httplib_response = conn.getresponse()
#     445         except BaseException as e:
#     446             # Remove the TypeError from the exception chain in
#     447             # Python 3 (including for exceptions like SystemExit).
#     448             # Otherwise it looks like a bug in the code.
# --> 449             six.raise_from(e, None)
#     450 except (SocketTimeout, BaseSSLError, SocketError) as e:
#     451     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File <string>:3, in raise_from(value, from_value)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/urllib3/connectionpool.py:444, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     441 except TypeError:
#     442     # Python 3
#     443     try:
# --> 444         httplib_response = conn.getresponse()
#     445     except BaseException as e:
#     446         # Remove the TypeError from the exception chain in
#     447         # Python 3 (including for exceptions like SystemExit).
#     448         # Otherwise it looks like a bug in the code.
#     449         six.raise_from(e, None)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/http/client.py:1374, in HTTPConnection.getresponse(self)
#    1372 try:
#    1373     try:
# -> 1374         response.begin()
#    1375     except ConnectionError:
#    1376         self.close()
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/http/client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/http/client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/socket.py:705, in SocketIO.readinto(self, b)
#     703 while True:
#     704     try:
# --> 705         return self._sock.recv_into(b)
#     706     except timeout:
#     707         self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
df = pd.DataFrame(article_lst)
df.columns=['Title','Abstract',"MainText"]

# %%
count_lst = []
for i in df["MainText"]:
    count_lst.append(len(i))
df['WordCount'] = count_lst
df['DOI'] = doi_lst
df.to_csv('JM2016-2020.csv')
df
# Out:
#                                                  Title  \
# 0    (When) are We Dynamically Optimal? A Psycholog...
# 1    (When) Does Third-Party Recognition for Design...
# 2    A Cinderella Story: How Past Identity Salience...
# 3    A Commentary on “Transformative Marketing: The...
# 4    A Meta-Analysis of When and How Advertising Cr...
# ..                                                 ...
# 233  Why Consumers Don't see the Benefits of Geneti...
# 234  Why the Dynamics of Competition Matter for Cat...
# 235  Why Unhappy Customers Are Unlikely to Share Th...
# 236  With Power Comes Responsibility: How Powerful ...
# 237  Within-Seller and Buyer–Seller Network Structu...
#
#                                               Abstract  \
# 0    A common assumption made in structural approac...
# 1    Third-party recognition for design excellence ...
# 2    Like Cinderella, many repurposed products invo...
# 3    Kumar's (2018) insightful editorial focuses on...
# 4    Although creativity is often considered a key ...
# ..                                                 ...
# 233  Evidence from four studies suggests that the m...
# 234  Category management (CM) has become a widespre...
# 235  For brands to thrive, they must understand con...
# 236  Firms sometimes engage in myopic management (e...
# 237  In business-to-business (B2B) markets, the suc...
#
#                                               MainText  WordCount  \
# 0    Prelude: The Empirical Strategy Wars\nIf there...      60188
# 1    Product design is a critical aspect of the inn...      74489
# 2    A worn-out airbag becomes a backpack. A leaky ...      76886
# 3    References\nAmit Raphael, and Schoemaker Paul ...        745
# 4    Creativity is important in marketing and is of...      74569
# ..                                                 ...        ...
# 233  Factors that influence consumer food preferenc...      64699
# 234  Organized retail is an important business sect...      62818
# 235  For brands to succeed, it is imperative that t...      74635
# 236  The motivation to satisfy Wall Street earnings...      71189
# 237  Increasing specialization, fragmentation, and ...      87041
#
#                           DOI
# 0          10.1509/jm.16.0154
# 1          10.1509/jm.15.0150
# 2    10.1177/0022242919872156
# 3            10.1509/jm.82.43
# 4    10.1177/0022242920929288
# ..                        ...
# 233        10.1509/jm.17.0100
# 234        10.1509/jm.15.0304
# 235  10.1177/0022242920920295
# 236  10.1177/0022242919831993
# 237  10.1177/0022242918812056
#
# [238 rows x 5 columns]

# %%
df1=pd.read_csv('JM2016-2020.csv')
df1
# Out:
#      Unnamed: 0                                              Title  \
# 0             0  (When) are We Dynamically Optimal? A Psycholog...
# 1             1  (When) Does Third-Party Recognition for Design...
# 2             2  A Cinderella Story: How Past Identity Salience...
# 3             3  A Commentary on “Transformative Marketing: The...
# 4             4  A Meta-Analysis of When and How Advertising Cr...
# ..          ...                                                ...
# 233         233  Why Consumers Don't see the Benefits of Geneti...
# 234         234  Why the Dynamics of Competition Matter for Cat...
# 235         235  Why Unhappy Customers Are Unlikely to Share Th...
# 236         236  With Power Comes Responsibility: How Powerful ...
# 237         237  Within-Seller and Buyer–Seller Network Structu...
#
#                                               Abstract  \
# 0    A common assumption made in structural approac...
# 1    Third-party recognition for design excellence ...
# 2    Like Cinderella, many repurposed products invo...
# 3    Kumar's (2018) insightful editorial focuses on...
# 4    Although creativity is often considered a key ...
# ..                                                 ...
# 233  Evidence from four studies suggests that the m...
# 234  Category management (CM) has become a widespre...
# 235  For brands to thrive, they must understand con...
# 236  Firms sometimes engage in myopic management (e...
# 237  In business-to-business (B2B) markets, the suc...
#
#                                               MainText  WordCount  \
# 0    Prelude: The Empirical Strategy Wars\nIf there...      60188
# 1    Product design is a critical aspect of the inn...      74489
# 2    A worn-out airbag becomes a backpack. A leaky ...      76886
# 3    References\nAmit Raphael, and Schoemaker Paul ...        745
# 4    Creativity is important in marketing and is of...      74569
# ..                                                 ...        ...
# 233  Factors that influence consumer food preferenc...      64699
# 234  Organized retail is an important business sect...      62818
# 235  For brands to succeed, it is imperative that t...      74635
# 236  The motivation to satisfy Wall Street earnings...      71189
# 237  Increasing specialization, fragmentation, and ...      87041
#
#                           DOI
# 0          10.1509/jm.16.0154
# 1          10.1509/jm.15.0150
# 2    10.1177/0022242919872156
# 3            10.1509/jm.82.43
# 4    10.1177/0022242920929288
# ..                        ...
# 233        10.1509/jm.17.0100
# 234        10.1509/jm.15.0304
# 235  10.1177/0022242920920295
# 236  10.1177/0022242919831993
# 237  10.1177/0022242918812056
#
# [238 rows x 6 columns]
