# %%
import sys
# !{sys.executable} -m pip install crossrefapi
# Out:
# Collecting crossrefapi
#   Downloading crossrefapi-1.5.0.tar.gz (20 kB)
# Requirement already satisfied: requests>=2.11.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from crossrefapi) (2.28.1)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from requests>=2.11.1->crossrefapi) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from requests>=2.11.1->crossrefapi) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from requests>=2.11.1->crossrefapi) (2022.9.24)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from requests>=2.11.1->crossrefapi) (1.26.12)
# Using legacy 'setup.py install' for crossrefapi, since package 'wheel' is not installed.
# Installing collected packages: crossrefapi
#     Running setup.py install for crossrefapi ... done
# Successfully installed crossrefapi-1.5.0
# WARNING: You are using pip version 21.2.4; however, version 22.2.2 is available.
# You should consider upgrading via the '/usr/local/bin/python3.10 -m pip install --upgrade pip' command.

# %%
from crossref.restful import Works
from crossref.restful import Journals
from time import sleep
import numpy as np
from bs4 import BeautifulSoup, NavigableString
import csv
import pandas as pd
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import pandas as pd
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
import random

# %%
doi_html = '/Users/richardpang/Desktop/extract_maintext/doi html/doi2011-2015.html'
doi_lst = []
with open(doi_html, 'r') as f:
    soup = BeautifulSoup(f, 'html.parser')
titles=soup.find_all('dl',{'class':"print-citation"})
for i in range(len(titles)):
    
    if "DOI:" in titles[i].get_text():
        doi = titles[i].get_text().split('DOI: ')[1].split(' ')[0][:-1]
        print(doi)
    # print(doi)
        doi_lst.append(doi)
df=pd.DataFrame(doi_lst)
len(df)
# Out:
# 10.1509/jmkg.75.4.136
# 10.1509/jm.14.0169
# 10.1509/jm.09.0081
# 10.1509/jm.12.0078
# 10.1509/jm.11.0330
# 10.1509/jm.11.0130
# 10.1509/jmkg.75.2.18
# 10.1509/jmkg.75.2.75
# 10.1509/jm.12.0106
# 10.1509/jm.11.0255
# 10.1509/jm.11.0297
# 10.1509/jmkg.75.3.1
# 10.1509/jmkg.75.5.53
# 10.1509/jm.09.0581
# 10.1509/jm.13.0410
# 10.1509/jm.13.0437
# 10.1509/jm.11.0105
# 10.1509/jm.10.0400
# 10.1509/jm.11.0145
# 10.1509/jm.09.0339
# 10.1509/jm.11.0485
# 10.1509/jmkg.75.4.196
# 10.1509/jm.13.0524
# 10.1509/jm.13.0228
# 10.1509/jm.10.0537
# 10.1509/jm.11.0544
# 10.1509/jm.14.0003
# 10.1509/jm.09.0589
# 10.1509/jmkg.75.4.183
# 10.1509/jmkg.75.3.18
# 10.1509/jm.13.0272
# 10.1509/jm.12.0190
# 10.1509/jmkg.75.3.66
# 10.1509/jm.12.0051
# 10.1509/jmkg.75.2.124
# 10.1509/jm.12.0052
# 10.1509/jm.10.0205
# 10.1509/jm.11.0599
# 10.1509/jm.11.0403
# 10.1509/jm.13.0026
# 10.1509/jm.12.0089
# 10.1509/jm.11.0245
# 10.1509/jm.10.0418
# 10.1509/jm.12.0421
# 10.1509/jm.11.0310
# 10.1509/jm.12.0317
# 10.1509/jmkg.75.3.118
# 10.1509/jm.12.0442
# 10.1509/jm.09.0486
# 10.1509/jm.10.0033
# 10.1509/jm.09.0362
# 10.1509/jm.11.0424
# 10.1509/jmkg.75.2.36
# 10.1509/jm.14.0351
# 10.1509/jm.09.0308
# 10.1509/jm.11.0205
# 10.1509/jmkg.75.3.27
# 10.1509/jm.11.0570
# 10.1509/jm.11.0264
# 10.1509/jm.11.0592
# 10.1509/jmkg.75.4.35
# 10.1509/jmkg.75.1.78
# 10.1509/jm.10.0529
# 10.1509/jm.14.0357
# 10.1509/jmkg.75.4.94
# 10.1509/jm.12.0471
# 10.1509/jm.79.1.1
# 10.1509/jmkg.75.5.71
# 10.1509/jmkg.75.4.53
# 10.1509/jm.11.0181
# 10.1509/jm.10.0494
# 10.1509/jm.12.0179
# 10.1509/jm.13.0509
# 10.1509/jm.13.0312
# 10.1509/jmkg.75.1.31
# 10.1509/jm.75.6.editorial
# 10.1509/jmkg.75.4.1
# 10.1509/jm.12.0408
# 10.1509/jm.10.0448
# 10.1509/jmkg.75.4.21
# 10.1509/jm.10.0416
# 10.1509/jm.11.0454
# 10.1509/jm.12.0167
# 10.1509/jm.13.0387
# 10.1509/jm.12.0422
# 10.1509/jm.11.0423
# 10.1509/jm.14.0100
# 10.1509/jm.14.0288
# 10.1509/jm.10.0231
# 10.1509/jm.10.0202
# 10.1509/jm.10.0406
# 10.1509/jm.12.0021
# 10.1509/jm.14.0284
# 10.1509/jm.11.0251
# 10.1509/jm.09.0395
# 10.1509/jm.13.0280
# 10.1509/jmkg.75.4.166
# 10.1509/jm.13.0212
# 10.1509/jm.12.0328
# 10.1509/jm.10.0413
# 10.1509/jm.11.0217
# 10.1509/jmkg.75.4.128
# 10.1509/jmkg.75.1.16
# 10.1509/jm.13.0301
# 10.1509/jmkg.75.5.18
# 10.1509/jmkg.75.3.132
# 10.1509/jmkg.75.5.120
# 10.1509/jm.76.4.i
# 10.1509/jm.76.2.i
# 10.1509/jm.76.1.i
# 10.1509/jmkg.75.5.i
# 10.1509/jmkg.75.4.i
# 10.1509/jmkg.75.1.i
# 10.1509/jm.75.6.i
# 10.1509/jm.76.3.i
# 10.1509/jmkg.75.2.i
# 10.1509/jm.75.6.i
# 10.1509/jm.13.0300
# 10.1509/jm.12.0468
# 10.1509/jm.12.0459
# 10.1509/jm.10.0280
# 10.1509/jm.12.0529
# 10.1509/jm.08.0204
# 10.1509/jm.12.0325
# 10.1509/jm.12.0296
# 10.1509/jm.13.0220
# 10.1509/jm.10.0015
# 10.1509/jm.13.0479
# 10.1509/jm.13.0522
# 10.1509/jm.12.0314
# 10.1509/jm.12.0020
# 10.1509/jmkg.75.1.60
# 10.1509/jm.09.0487
# 10.1509/jmkg.75.4.225
# 10.1509/jm.10.0162
# 10.1509/jm.13.0075
# 10.1509/jm.11.0560
# 10.1509/jm.09.0094
# 10.1509/jm.13.0174
# 10.1509/jm.09.0199
# 10.1509/jm.10.0444
# 10.1509/jm.13.0059
# 10.1509/jm.13.0218
# 10.1509/jm.14.0199
# 10.1509/jm.13.0198
# 10.1509/jm.11.0528
# 10.1509/jm.11.0508
# 10.1509/jmkg.75.4.211
# 10.1509/jm.10.0441
# 10.1509/jm.11.0529
# 10.1509/jmkg.75.2.1
# 10.1509/jm.13.0253
# 10.1509/jmkg.75.3.99
# 10.1509/jm.11.0164
# 10.1509/jm.12.0228
# 10.1509/jm.12.0338
# 10.1509/jm.11.0112
# 10.1509/jmkg.75.3.83
# 10.1509/jm.11.0286
# 10.1509/jmkg.75.1.96
# 10.1509/jm.09.0363
# 10.1509/jmkg.75.1.46
# 10.1509/jm.14.0107
# 10.1509/jm.10.0271
# 10.1509/jmkg.75.4.132
# 10.1509/jm.11.0219
# 10.1509/jm.11.0566
# 10.1509/jm.10.0534
# 10.1509/jm.75.2.93
# 10.1509/jm.10.0419
# 10.1509/jm.10.0414
# 10.1509/jm.10.0088
# 10.1509/jm.12.0527
# 10.1509/jm.09.0420
# 10.1509/jm.14.0273
# 10.1509/jmkg.75.3.49
# 10.1509/jm.14.0091
# 10.1509/jm.12.0303
# 10.1509/jm.12.0060
# 10.1509/jm.09.0202
# 10.1509/jm.10.0209
# 10.1509/jm.10.0377
# 10.1509/jm.14.0444
# 10.1509/jm.11.0443
# 10.1509/jmkg.75.4.155
# 10.1509/jmkg.75.4.68
# 10.1509/jm.11.0173
# 10.1509/jm.11.0431
# 10.1509/jm.11.0316
# 10.1509/jm.11.0428
# 10.1509/jm.10.0348
# 10.1509/jmkg.75.4.110
# 10.1509/jmkg.75.4.3
# 10.1509/jmkg.75.5.34
# 10.1509/jm.14.0244
# 10.1509/jm.13.0263
# 10.1509/jm.11.0349
# 10.1509/jm.09.0209
# 10.1509/jm.09.0320
# 10.1509/jmkg.75.2.109
# 10.1509/jm.11.0436
# 10.1509/jm.10.0073
# 10.1509/jmkg.75.1.1
# 10.1509/jm.11.0011
# 10.1509/jm.14.0018
# 10.1509/jm.10.0522
# 10.1509/jmkg.75.5.88
# 10.1509/jm.13.0521
# 10.1509/jmkg.75.4.86
# 10.1509/jm.11.0356
# 10.1509/jm.13.0505
# 10.1509/jm.11.0495
# 10.1509/jm.13.0475
# 10.1509/jm.12.0151
# 10.1509/jm.10.0462
# 10.1509/jm.10.0145
# 10.1509/jm.11.0400
# 10.1509/jmkg.75.5.105
# 10.1509/jm.12.0196
# 10.1509/jm.13.0185
# 10.1509/jm.13.0286
# 10.1509/jm.10.0047
# 10.1509/jm.13.0490
# 10.1509/jm.11.0222
# 10.1509/jmkg.75.4.129
# 10.1509/jm.12.0056
# 10.1509/jm.15.0105
# 10.1509/jm.14.0202
# 10.1509/jm.10.0445
# 10.1509/jm.11.0463
# 10.1509/jm.12.0404
# 10.1509/jm.09.0416
# 10.1509/jm.10.0229
# 10.1509/jm.13.0303
# 10.1509/jm.11.0278
# 10.1509/jm.09.0512
# 10.1509/jm.09.0034
# 10.1509/jm.11.0610
# 10.1509/jm.11.0477
# 10.1509/jm.11.0510
# 10.1509/jm.10.0368
# 10.1509/jm.10.0443
# 10.1509/jmkg.75.2.55
# 10.1509/jm.11.0504
# 10.1509/jm.12.0344
# 10.1509/jm.11.0261
# 10.1509/jm.12.0166
# 10.1509/jm.10.0182
# 10.1509/jmkg.75.1.109
# 10.1509/jmkg.75.5.1
# 10.1509/jm.13.0104
# 10.1509/jm.11.0225
# 252

# %%
url = 'https://journals.sagepub.com/doi/full/10.1509/jmkg.75.2.18'

# %%
url_lst = []
for i in range(len(doi_lst)):
    url = 'https://journals.sagepub.com/doi/full/' + doi_lst[i]
    url_lst.append(url)
len(url_lst)
# Out:
# 252

# %% [markdown]
# # Scraping

# %%
#For ChromeDriver version 79.0.3945.16 or over
options = Options()
options.add_argument('--disable-blink-features=AutomationControlled') 

#Open Browser
driver = webdriver.Chrome(executable_path='/Users/richardpang/.wdm/drivers/chromedriver/mac64/106.0.5249/chromedriver',options=options)
article_lst = []
count = 0
for i in range(len(url_lst)):
# driver = webdriver.Chrome( '/Users/richardpang/.wdm/drivers/chromedriver/mac64/106.0.5249/chromedriver')
    driver.get(url_lst[i])
    element = driver.find_elements(By.TAG_NAME, 'div')
    element = driver.find_elements(By.CLASS_NAME, 'core-container')
    # print(len(element))
    if len(element)>4:
        title = element[0].text.split('\n')[3]
        abstract = element[2].text.split('\n')[1]
        main_text = element[3].text
        doi = doi_lst[i]
        article  = [title,abstract,main_text,doi]
        article_lst.append(article)
    count += 1
    if count%10 ==0:
        print(count, 'articles have been collected.')
    sleep(np.random.randint(6, 7))
# driver.quit()
article_df = pd.DataFrame(article_lst)
article_df
# Out:
# /var/folders/28/rtg76x2d1m791yxskrhmnffc0000gn/T/ipykernel_36095/1608752158.py:6: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(executable_path='/Users/richardpang/.wdm/drivers/chromedriver/mac64/106.0.5249/chromedriver',options=options)
# 10 articles have been collected.
# 20 articles have been collected.
# 30 articles have been collected.
# 40 articles have been collected.
# 50 articles have been collected.
# 60 articles have been collected.
# 70 articles have been collected.
# 80 articles have been collected.
# 90 articles have been collected.
# 100 articles have been collected.
# 110 articles have been collected.
# 120 articles have been collected.
# 130 articles have been collected.
# 140 articles have been collected.
# 150 articles have been collected.
# 160 articles have been collected.
# 170 articles have been collected.
# 180 articles have been collected.
# 190 articles have been collected.
# 200 articles have been collected.
# 210 articles have been collected.
# 220 articles have been collected.
# 230 articles have been collected.
# 240 articles have been collected.
# 250 articles have been collected.
#                                                      0  \
# 0    A Framework for Conceptual Contributions in Ma...
# 1    A Meta-Analysis of Electronic Word-of-Mouth El...
# 2    Adding Bricks to Clicks: Predicting the Patter...
# 3    Aggressive Marketing Strategy following Equity...
# 4    All That is Users Might Not be Gold: How Label...
# ..                                                 ...
# 221  Who or What to Believe: Trust and the Differen...
# 222  Why do Customers Get more than They Need? How ...
# 223  Will Consumers be Willing to Pay more when you...
# 224  Willing to Pay More, Eager to Pay Less: The Ro...
# 225  You get what you Pay for: The Effect of Top Ex...
#
#                                                      1  \
# 0    Conceptual advances are critical to the vitali...
# 1    The authors conduct a meta-analysis on the eff...
# 2    The authors propose a conceptual framework to ...
# 3    Firms raise a significant amount of funds and ...
# 4    An emerging literature stream posits that draw...
# ..                                                 ...
# 221  Participants in three studies read advertiseme...
# 222  The capability level of a product that a firm ...
# 223  Network effects and standards competition intr...
# 224  This article is the first to empirically exami...
# 225  Although there is literature on how top execut...
#
#                                                      2                      3
# 0    The 75th anniversary of Journal of Marketing (...  10.1509/jmkg.75.4.136
# 1    Electronic word of mouth (eWOM)—Internet-media...     10.1509/jm.14.0169
# 2    As new technologies opened new paths to market...     10.1509/jm.09.0081
# 3    General Motors Co., which raised more than $20...     10.1509/jm.12.0078
# 4    It seems that harnessing users' creative poten...     10.1509/jm.11.0330
# ..                                                 ...                    ...
# 221  Communicators often portray products, brands, ...     10.1509/jm.12.0166
# 222  The extant literature on product management is...     10.1509/jm.10.0182
# 223  Network effects are becoming increasingly impo...    10.1509/jmkg.75.5.1
# 224  Today's business world commonly accepts the hi...     10.1509/jm.13.0104
# 225  If you pick the right people and give them the...     10.1509/jm.11.0225
#
# [226 rows x 4 columns]

# %%
df = pd.DataFrame(article_lst)
df.columns=['Title','Abstract',"MainText","DOI"]

# %%
len(article_lst)
# Out:
# 226

# %%
count_lst = []
for i in df["MainText"]:
    count_lst.append(len(i))
df['WordCount'] = count_lst

df.to_csv('JM2011-2015.csv')
df
# Out:
#                                                  Title  \
# 0    A Framework for Conceptual Contributions in Ma...
# 1    A Meta-Analysis of Electronic Word-of-Mouth El...
# 2    Adding Bricks to Clicks: Predicting the Patter...
# 3    Aggressive Marketing Strategy following Equity...
# 4    All That is Users Might Not be Gold: How Label...
# ..                                                 ...
# 221  Who or What to Believe: Trust and the Differen...
# 222  Why do Customers Get more than They Need? How ...
# 223  Will Consumers be Willing to Pay more when you...
# 224  Willing to Pay More, Eager to Pay Less: The Ro...
# 225  You get what you Pay for: The Effect of Top Ex...
#
#                                               Abstract  \
# 0    Conceptual advances are critical to the vitali...
# 1    The authors conduct a meta-analysis on the eff...
# 2    The authors propose a conceptual framework to ...
# 3    Firms raise a significant amount of funds and ...
# 4    An emerging literature stream posits that draw...
# ..                                                 ...
# 221  Participants in three studies read advertiseme...
# 222  The capability level of a product that a firm ...
# 223  Network effects and standards competition intr...
# 224  This article is the first to empirically exami...
# 225  Although there is literature on how top execut...
#
#                                               MainText                    DOI  \
# 0    The 75th anniversary of Journal of Marketing (...  10.1509/jmkg.75.4.136
# 1    Electronic word of mouth (eWOM)—Internet-media...     10.1509/jm.14.0169
# 2    As new technologies opened new paths to market...     10.1509/jm.09.0081
# 3    General Motors Co., which raised more than $20...     10.1509/jm.12.0078
# 4    It seems that harnessing users' creative poten...     10.1509/jm.11.0330
# ..                                                 ...                    ...
# 221  Communicators often portray products, brands, ...     10.1509/jm.12.0166
# 222  The extant literature on product management is...     10.1509/jm.10.0182
# 223  Network effects are becoming increasingly impo...    10.1509/jmkg.75.5.1
# 224  Today's business world commonly accepts the hi...     10.1509/jm.13.0104
# 225  If you pick the right people and give them the...     10.1509/jm.11.0225
#
#      WordCount
# 0        87645
# 1        80496
# 2        72376
# 3        77089
# 4        81417
# ..         ...
# 221      69560
# 222      47625
# 223      73448
# 224      76611
# 225      71465
#
# [226 rows x 5 columns]

# %%
df1=pd.read_csv('JM2011-2015.csv')
count = 0
for i in df1['WordCount']:
    if i > 10000:
        count += 1
df1
# Out:
#      Unnamed: 0                                              Title  \
# 0             0  A Comparative Longitudinal Analysis of Theoret...
# 1             1     A Cultural Models Approach to Service Recovery
# 2             2  A Global Investigation into the Constellation ...
# 3             3  A Longitudinal Analysis of Customer Satisfacti...
# 4             4  A Penny for Your Thoughts: Referral Reward Pro...
# ..          ...                                                ...
# 186         186  When Marketing Strategy First Meets Wall Stree...
# 187         187  When to Give up Control of Outsourced New Prod...
# 188         188  Where did all that Money Go? Understanding how...
# 189         189  Why Are Some Salespeople Better at Adapting to...
# 190         190  Why do Older Consumers Buy Older Brands? The R...
#
#                                               Abstract  \
# 0    Four theoretical perspectives currently domina...
# 1    Service recovery research remains conflicted i...
# 2    In this article, the authors introduce attitud...
# 3    Customer loyalty is an important strategic obj...
# 4    Because referral reward programs reward existi...
# ..                                                 ...
# 186  This article examines the role of marketing in...
# 187  The author investigates the impact of client c...
# 188  All types of consumer expenditures ultimately ...
# 189  This study empirically examines the longitudin...
# 190  The authors compare three mechanisms that may ...
#
#                                               MainText                    DOI  \
# 0    Successful interorganizational relationships a...  10.1509/jmkg.71.4.172
# 1    Research in consumer behavior suggests that mo...  10.1509/jmkg.71.3.194
# 2    The globalization of the marketplace is one of...   10.1509/jmkg.74.6.18
# 3    Customer loyalty is an important strategic obj...  10.1509/jmkg.71.1.067
# 4    Word of mouth (WOM), at one time viewed as a s...  10.1509/jmkg.71.1.084
# ..                                                 ...                    ...
# 186  How can marketing help create firm shareholder...  10.1509/jmkg.72.5.098
# 187  Until recently, firms conducted virtually all ...  10.1509/jmkg.71.1.049
# 188  The majority of models of consumer demand in t...  10.1509/jmkg.72.6.109
# 189  Arecent census by the U.S. Bureau of Labor Sta...  10.1509/jmkg.74.3.065
# 190  In multiple and important categories, older co...  10.1509/jmkg.74.5.104
#
#      WordCount
# 0        83283
# 1        85988
# 2        81127
# 3        62324
# 4        54364
# ..         ...
# 186      51085
# 187      66990
# 188      73282
# 189      60258
# 190      61433
#
# [191 rows x 6 columns]
